# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import StratifiedKFold
from lightgbm.sklearn import LGBMClassifier
from sklearn.metrics import mean_squared_error, mean_absolute_error, log_loss, accuracy_score
from sklearn.feature_extraction.text import CountVectorizer
from scipy import sparse
from scipy.stats import kurtosis
import time
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### 方案思路：33分类
#
# - label为还款日期距成交日期的天数，可能的情况有0天到31天，未还款定义为32，一共33个类别。
#
# - 预测出每个label对应的概率，然后分别乘以应还的金额，就是每天需要还的金额。
#
# - 线上分数：8500左右。
#
# - 特征还有很多可以做，并且behavior表还没用，repay_logs表也还有很多有价值的东西没提取，因此分数还能提高。
#
# - 主要问题：线下验证分数不靠谱，线上波动很大。
#
# - 线下分类acc很低，需要找准特征工程的方向来提高分类准确率，此题当作分类任务和当作回归任务时的特征工程方向可能差别很大。

# %%
train_df = pd.read_csv('dataset/train.csv', parse_dates=['auditing_date', 'due_date', 'repay_date'])

train_df['repay_date'] = train_df[['due_date', 'repay_date']].apply(

    lambda x: x['repay_date'] if x['repay_date'] != '\\N' else x['due_date'], axis=1

)

train_df['repay_amt'] = train_df['repay_amt'].apply(lambda x: x if x != '\\N' else 0).astype('float32')

train_df['label'] = (train_df['repay_date'] - train_df['auditing_date']).dt.days

train_df.loc[train_df['repay_amt'] == 0, 'label'] = 32

clf_labels = train_df['label'].values

amt_labels = train_df['repay_amt'].values

del train_df['label'], train_df['repay_amt'], train_df['repay_date']

train_due_amt_df = train_df[['due_amt']]

train_num = train_df.shape[0]

# %%
test_df = pd.read_csv('dataset/test.csv', parse_dates=['auditing_date', 'due_date'])
sub = test_df[['listing_id', 'auditing_date', 'due_amt']]
df = pd.concat([train_df, test_df], axis=0, ignore_index=True)

# %%
listing_info_df = pd.read_csv('dataset/listing_info.csv')

del listing_info_df['user_id'], listing_info_df['auditing_date']

df = df.merge(listing_info_df, on='listing_id', how='left')

# %%
# 表中有少数user不止一条记录，因此按日期排序，去重，只保留最新的一条记录。

user_info_df = pd.read_csv('dataset/user_info.csv', parse_dates=['reg_mon', 'insertdate'])

user_info_df.rename(columns={'insertdate': 'info_insert_date'}, inplace=True)

user_info_df = user_info_df.sort_values(by='info_insert_date', ascending=False).drop_duplicates('user_id').reset_index(drop=True)

df = df.merge(user_info_df, on='user_id', how='left')

# %%
# 同上

user_tag_df = pd.read_csv('dataset/user_taglist.csv', parse_dates=['insertdate'])

user_tag_df.rename(columns={'insertdate': 'tag_insert_date'}, inplace=True)

user_tag_df = user_tag_df.sort_values(by='tag_insert_date', ascending=False).drop_duplicates('user_id').reset_index(drop=True)

df = df.merge(user_tag_df, on='user_id', how='left')

# %%
# 历史记录表能做的特征远不止这些

repay_log_df = pd.read_csv('dataset/user_repay_logs.csv', parse_dates=['due_date', 'repay_date'])

# 由于题目任务只预测第一期的还款情况，因此这里只保留第一期的历史记录。当然非第一期的记录也能提取很多特征。

repay_log_df = repay_log_df[repay_log_df['order_id'] == 1].reset_index(drop=True)

repay_log_df['repay'] = repay_log_df['repay_date'].astype('str').apply(lambda x: 1 if x != '2200-01-01' else 0)

repay_log_df['early_repay_days'] = (repay_log_df['due_date'] - repay_log_df['repay_date']).dt.days

repay_log_df['early_repay_days'] = repay_log_df['early_repay_days'].apply(lambda x: x if x >= 0 else -1)

for f in ['listing_id', 'order_id', 'due_date', 'repay_date', 'repay_amt']:

    del repay_log_df[f]

group = repay_log_df.groupby('user_id', as_index=False)

repay_log_df = repay_log_df.merge(

    group['repay'].agg({'repay_mean': 'mean'}), on='user_id', how='left'

)

repay_log_df = repay_log_df.merge(

    group['early_repay_days'].agg({

        'early_repay_days_max': 'max', 'early_repay_days_median': 'median', 'early_repay_days_sum': 'sum',

        'early_repay_days_mean': 'mean', 'early_repay_days_std': 'std'

    }), on='user_id', how='left'

)

repay_log_df = repay_log_df.merge(

    group['due_amt'].agg({

        'due_amt_max': 'max', 'due_amt_min': 'min', 'due_amt_median': 'median',

        'due_amt_mean': 'mean', 'due_amt_sum': 'sum', 'due_amt_std': 'std',

        'due_amt_skew': 'skew', 'due_amt_kurt': kurtosis, 'due_amt_ptp': np.ptp

    }), on='user_id', how='left'

)

del repay_log_df['repay'], repay_log_df['early_repay_days'], repay_log_df['due_amt']

repay_log_df = repay_log_df.drop_duplicates('user_id').reset_index(drop=True)

df = df.merge(repay_log_df, on='user_id', how='left')



cate_cols = ['gender', 'cell_province', 'id_province', 'id_city']

for f in cate_cols:

    df[f] = df[f].map(dict(zip(df[f].unique(), range(df[f].nunique())))).astype('int32')



df['due_amt_per_days'] = df['due_amt'] / (train_df['due_date'] - train_df['auditing_date']).dt.days

date_cols = ['auditing_date', 'due_date', 'reg_mon', 'info_insert_date', 'tag_insert_date']

for f in date_cols:

    if f in ['reg_mon', 'info_insert_date', 'tag_insert_date']:

        df[f + '_year'] = df[f].dt.year

    df[f + '_month'] = df[f].dt.month

    if f in ['auditing_date', 'due_date', 'info_insert_date', 'tag_insert_date']:

        df[f + '_day'] = df[f].dt.day

        df[f + '_dayofweek'] = df[f].dt.dayofweek

df.drop(columns=date_cols, axis=1, inplace=True)



df['taglist'] = df['taglist'].astype('str').apply(lambda x: x.strip().replace('|', ' ').strip())

tag_cv = CountVectorizer(min_df=10, max_df=0.9).fit_transform(df['taglist'])



del df['user_id'], df['listing_id'], df['taglist']



df = pd.get_dummies(df, columns=cate_cols)

df = sparse.hstack((df.values, tag_cv), format='csr', dtype='float32')

train_values, test_values = df[:train_num], df[train_num:]





print(train_values.shape)
# Out:
# (1000000, 6435)

# %%
# 五折验证也可以改成一次验证，按时间划分训练集和验证集，以避免由于时序引起的数据穿越问题。

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=2019)

clf = LGBMClassifier(

    learning_rate=0.05,

    n_estimators=10000,

    subsample=0.8,

    subsample_freq=1,

    colsample_bytree=0.8,

    random_state=2019

)

amt_oof = np.zeros(train_num)

prob_oof = np.zeros((train_num, 33))

test_pred_prob = np.zeros((test_values.shape[0], 33))

for i, (trn_idx, val_idx) in enumerate(skf.split(train_values, clf_labels)):

    print(i, 'fold...')

    t = time.time()



    trn_x, trn_y = train_values[trn_idx], clf_labels[trn_idx]

    val_x, val_y = train_values[val_idx], clf_labels[val_idx]

    val_repay_amt = amt_labels[val_idx]

    val_due_amt = train_due_amt_df.iloc[val_idx]



    clf.fit(

        trn_x, trn_y,

        eval_set=[(trn_x, trn_y), (val_x, val_y)],

        early_stopping_rounds=100, verbose=5

    )

    # shepe = (-1, 33)

    val_pred_prob_everyday = clf.predict_proba(val_x, num_iteration=clf.best_iteration_)

    prob_oof[val_idx] = val_pred_prob_everyday

    val_pred_prob_today = [val_pred_prob_everyday[i][val_y[i]] for i in range(val_pred_prob_everyday.shape[0])]

    val_pred_repay_amt = val_due_amt['due_amt'].values * val_pred_prob_today

    print('val rmse:', np.sqrt(mean_squared_error(val_repay_amt, val_pred_repay_amt)))

    print('val mae:', mean_absolute_error(val_repay_amt, val_pred_repay_amt))

    amt_oof[val_idx] = val_pred_repay_amt

    test_pred_prob += clf.predict_proba(test_values, num_iteration=clf.best_iteration_) / skf.n_splits



    print('runtime: {}\n'.format(time.time() - t))



print('\ncv rmse:', np.sqrt(mean_squared_error(amt_labels, amt_oof)))

print('cv mae:', mean_absolute_error(amt_labels, amt_oof))

print('cv logloss:', log_loss(clf_labels, prob_oof))

print('cv acc:', accuracy_score(clf_labels, np.argmax(prob_oof, axis=1)))



prob_cols = ['prob_{}'.format(i) for i in range(33)]

for i, f in enumerate(prob_cols):

    sub[f] = test_pred_prob[:, i]
# Out:
# 0 fold...
# Training until validation scores don't improve for 100 rounds.
# [5]	valid_0's multi_logloss: 2.94769	valid_1's multi_logloss: 2.94892
# [10]	valid_0's multi_logloss: 2.70739	valid_1's multi_logloss: 2.71038
# [15]	valid_0's multi_logloss: 2.55546	valid_1's multi_logloss: 2.56035
# [20]	valid_0's multi_logloss: 2.44762	valid_1's multi_logloss: 2.45448
# [25]	valid_0's multi_logloss: 2.36871	valid_1's multi_logloss: 2.37746
# [30]	valid_0's multi_logloss: 2.30763	valid_1's multi_logloss: 2.31834
# [35]	valid_0's multi_logloss: 2.25906	valid_1's multi_logloss: 2.27178
# [40]	valid_0's multi_logloss: 2.22019	valid_1's multi_logloss: 2.23499
# [45]	valid_0's multi_logloss: 2.18915	valid_1's multi_logloss: 2.20611
# [50]	valid_0's multi_logloss: 2.16377	valid_1's multi_logloss: 2.18297
# [55]	valid_0's multi_logloss: 2.14259	valid_1's multi_logloss: 2.16412
# [60]	valid_0's multi_logloss: 2.12481	valid_1's multi_logloss: 2.14871
# [65]	valid_0's multi_logloss: 2.10985	valid_1's multi_logloss: 2.13615
# [70]	valid_0's multi_logloss: 2.0968	valid_1's multi_logloss: 2.12556
# [75]	valid_0's multi_logloss: 2.08559	valid_1's multi_logloss: 2.11703
# [80]	valid_0's multi_logloss: 2.07577	valid_1's multi_logloss: 2.10989
# [85]	valid_0's multi_logloss: 2.06706	valid_1's multi_logloss: 2.10392
# [90]	valid_0's multi_logloss: 2.05928	valid_1's multi_logloss: 2.09893
# [95]	valid_0's multi_logloss: 2.05232	valid_1's multi_logloss: 2.09482
# [100]	valid_0's multi_logloss: 2.04587	valid_1's multi_logloss: 2.09133
# [105]	valid_0's multi_logloss: 2.03995	valid_1's multi_logloss: 2.08839
# [110]	valid_0's multi_logloss: 2.03444	valid_1's multi_logloss: 2.08584
# [115]	valid_0's multi_logloss: 2.02921	valid_1's multi_logloss: 2.08365
# [120]	valid_0's multi_logloss: 2.02419	valid_1's multi_logloss: 2.08179
# [125]	valid_0's multi_logloss: 2.01957	valid_1's multi_logloss: 2.08023
# [130]	valid_0's multi_logloss: 2.01518	valid_1's multi_logloss: 2.07896
# [135]	valid_0's multi_logloss: 2.01092	valid_1's multi_logloss: 2.0778
# [140]	valid_0's multi_logloss: 2.00668	valid_1's multi_logloss: 2.07668
# [145]	valid_0's multi_logloss: 2.00269	valid_1's multi_logloss: 2.07578
# [150]	valid_0's multi_logloss: 1.99888	valid_1's multi_logloss: 2.07503
# [155]	valid_0's multi_logloss: 1.99508	valid_1's multi_logloss: 2.07428
# [160]	valid_0's multi_logloss: 1.99146	valid_1's multi_logloss: 2.07363
# [165]	valid_0's multi_logloss: 1.98801	valid_1's multi_logloss: 2.07319
# [170]	valid_0's multi_logloss: 1.98454	valid_1's multi_logloss: 2.07268
# [175]	valid_0's multi_logloss: 1.98119	valid_1's multi_logloss: 2.07224
# [180]	valid_0's multi_logloss: 1.97786	valid_1's multi_logloss: 2.07181
# [185]	valid_0's multi_logloss: 1.97469	valid_1's multi_logloss: 2.07148
# [190]	valid_0's multi_logloss: 1.97158	valid_1's multi_logloss: 2.07111
# [195]	valid_0's multi_logloss: 1.9685	valid_1's multi_logloss: 2.07087
# [200]	valid_0's multi_logloss: 1.96545	valid_1's multi_logloss: 2.07063
# [205]	valid_0's multi_logloss: 1.96242	valid_1's multi_logloss: 2.07034
# [210]	valid_0's multi_logloss: 1.95943	valid_1's multi_logloss: 2.07
# [215]	valid_0's multi_logloss: 1.95654	valid_1's multi_logloss: 2.06979
# [220]	valid_0's multi_logloss: 1.95373	valid_1's multi_logloss: 2.06964
# [225]	valid_0's multi_logloss: 1.95095	valid_1's multi_logloss: 2.06947
# [230]	valid_0's multi_logloss: 1.9482	valid_1's multi_logloss: 2.06931
# [235]	valid_0's multi_logloss: 1.94553	valid_1's multi_logloss: 2.06918
# [240]	valid_0's multi_logloss: 1.94286	valid_1's multi_logloss: 2.069
# [245]	valid_0's multi_logloss: 1.94026	valid_1's multi_logloss: 2.06885
# [250]	valid_0's multi_logloss: 1.93766	valid_1's multi_logloss: 2.06864
# [255]	valid_0's multi_logloss: 1.93512	valid_1's multi_logloss: 2.06848
# [260]	valid_0's multi_logloss: 1.93259	valid_1's multi_logloss: 2.06833
# [265]	valid_0's multi_logloss: 1.93011	valid_1's multi_logloss: 2.06819
# [270]	valid_0's multi_logloss: 1.92774	valid_1's multi_logloss: 2.06815
# [275]	valid_0's multi_logloss: 1.92532	valid_1's multi_logloss: 2.06801
# [280]	valid_0's multi_logloss: 1.92294	valid_1's multi_logloss: 2.06789
# [285]	valid_0's multi_logloss: 1.92061	valid_1's multi_logloss: 2.0678
# [290]	valid_0's multi_logloss: 1.91823	valid_1's multi_logloss: 2.06771
# [295]	valid_0's multi_logloss: 1.91593	valid_1's multi_logloss: 2.06765
# [300]	valid_0's multi_logloss: 1.91362	valid_1's multi_logloss: 2.06754
# [305]	valid_0's multi_logloss: 1.91139	valid_1's multi_logloss: 2.06748
# [310]	valid_0's multi_logloss: 1.90919	valid_1's multi_logloss: 2.06744
# [315]	valid_0's multi_logloss: 1.9069	valid_1's multi_logloss: 2.06735
# [320]	valid_0's multi_logloss: 1.90468	valid_1's multi_logloss: 2.06729
# [325]	valid_0's multi_logloss: 1.90245	valid_1's multi_logloss: 2.06723
# [330]	valid_0's multi_logloss: 1.90026	valid_1's multi_logloss: 2.06717
# [335]	valid_0's multi_logloss: 1.89814	valid_1's multi_logloss: 2.06712
# [340]	valid_0's multi_logloss: 1.89604	valid_1's multi_logloss: 2.06708
# [345]	valid_0's multi_logloss: 1.89392	valid_1's multi_logloss: 2.06706
# [350]	valid_0's multi_logloss: 1.89173	valid_1's multi_logloss: 2.0669
# [355]	valid_0's multi_logloss: 1.88962	valid_1's multi_logloss: 2.06684
# [360]	valid_0's multi_logloss: 1.8876	valid_1's multi_logloss: 2.06679
# [365]	valid_0's multi_logloss: 1.88555	valid_1's multi_logloss: 2.06676
# [370]	valid_0's multi_logloss: 1.88349	valid_1's multi_logloss: 2.06663
# [375]	valid_0's multi_logloss: 1.8815	valid_1's multi_logloss: 2.06663
# [380]	valid_0's multi_logloss: 1.8795	valid_1's multi_logloss: 2.06664
# [385]	valid_0's multi_logloss: 1.87742	valid_1's multi_logloss: 2.06649
# [390]	valid_0's multi_logloss: 1.87547	valid_1's multi_logloss: 2.06645
# [395]	valid_0's multi_logloss: 1.87352	valid_1's multi_logloss: 2.06642
# [400]	valid_0's multi_logloss: 1.87154	valid_1's multi_logloss: 2.06642
# [405]	valid_0's multi_logloss: 1.86961	valid_1's multi_logloss: 2.06637
# [410]	valid_0's multi_logloss: 1.86769	valid_1's multi_logloss: 2.0664
# [415]	valid_0's multi_logloss: 1.86577	valid_1's multi_logloss: 2.0664
# [420]	valid_0's multi_logloss: 1.86388	valid_1's multi_logloss: 2.06639
# [425]	valid_0's multi_logloss: 1.86187	valid_1's multi_logloss: 2.06632
# [430]	valid_0's multi_logloss: 1.85999	valid_1's multi_logloss: 2.06631
# [435]	valid_0's multi_logloss: 1.85811	valid_1's multi_logloss: 2.06631
# [440]	valid_0's multi_logloss: 1.85621	valid_1's multi_logloss: 2.06627
# [445]	valid_0's multi_logloss: 1.85438	valid_1's multi_logloss: 2.0663
# [450]	valid_0's multi_logloss: 1.8526	valid_1's multi_logloss: 2.06633
# [455]	valid_0's multi_logloss: 1.85079	valid_1's multi_logloss: 2.06635
# [460]	valid_0's multi_logloss: 1.84894	valid_1's multi_logloss: 2.06635
# [465]	valid_0's multi_logloss: 1.84713	valid_1's multi_logloss: 2.06634
# [470]	valid_0's multi_logloss: 1.84538	valid_1's multi_logloss: 2.06634
# [475]	valid_0's multi_logloss: 1.84357	valid_1's multi_logloss: 2.06636
# [480]	valid_0's multi_logloss: 1.8418	valid_1's multi_logloss: 2.06636
# [485]	valid_0's multi_logloss: 1.84005	valid_1's multi_logloss: 2.06637
# [490]	valid_0's multi_logloss: 1.83826	valid_1's multi_logloss: 2.06634
# [495]	valid_0's multi_logloss: 1.83648	valid_1's multi_logloss: 2.06635
# [500]	valid_0's multi_logloss: 1.83474	valid_1's multi_logloss: 2.06636
# [505]	valid_0's multi_logloss: 1.83297	valid_1's multi_logloss: 2.06636
# [510]	valid_0's multi_logloss: 1.83123	valid_1's multi_logloss: 2.06635
# [515]	valid_0's multi_logloss: 1.82949	valid_1's multi_logloss: 2.06635
# [520]	valid_0's multi_logloss: 1.82774	valid_1's multi_logloss: 2.06636
# [525]	valid_0's multi_logloss: 1.82608	valid_1's multi_logloss: 2.06636
# [530]	valid_0's multi_logloss: 1.82442	valid_1's multi_logloss: 2.0664
# [535]	valid_0's multi_logloss: 1.82278	valid_1's multi_logloss: 2.06645
# Early stopping, best iteration is:
# [439]	valid_0's multi_logloss: 1.85658	valid_1's multi_logloss: 2.06627
# val rmse: 465.2648708750759
# val mae: 288.3214899433093
# runtime: 3962.6817593574524
#
# 1 fold...
# Training until validation scores don't improve for 100 rounds.
# [5]	valid_0's multi_logloss: 2.94748	valid_1's multi_logloss: 2.94962
# [10]	valid_0's multi_logloss: 2.70532	valid_1's multi_logloss: 2.70967
# [15]	valid_0's multi_logloss: 2.55219	valid_1's multi_logloss: 2.55874
# [20]	valid_0's multi_logloss: 2.44539	valid_1's multi_logloss: 2.45402
# [25]	valid_0's multi_logloss: 2.36624	valid_1's multi_logloss: 2.37699
# [30]	valid_0's multi_logloss: 2.30543	valid_1's multi_logloss: 2.31833
# [35]	valid_0's multi_logloss: 2.25741	valid_1's multi_logloss: 2.27243
# [40]	valid_0's multi_logloss: 2.21898	valid_1's multi_logloss: 2.2361
# [45]	valid_0's multi_logloss: 2.18832	valid_1's multi_logloss: 2.20765
# [50]	valid_0's multi_logloss: 2.16265	valid_1's multi_logloss: 2.18427
# [55]	valid_0's multi_logloss: 2.14178	valid_1's multi_logloss: 2.16573
# [60]	valid_0's multi_logloss: 2.12403	valid_1's multi_logloss: 2.15038
# [65]	valid_0's multi_logloss: 2.10877	valid_1's multi_logloss: 2.13762
# [70]	valid_0's multi_logloss: 2.09611	valid_1's multi_logloss: 2.12758
# [75]	valid_0's multi_logloss: 2.08497	valid_1's multi_logloss: 2.11912
# [80]	valid_0's multi_logloss: 2.07545	valid_1's multi_logloss: 2.11225
# [85]	valid_0's multi_logloss: 2.06676	valid_1's multi_logloss: 2.10631
# [90]	valid_0's multi_logloss: 2.0588	valid_1's multi_logloss: 2.10119
# [95]	valid_0's multi_logloss: 2.0517	valid_1's multi_logloss: 2.09696
# [100]	valid_0's multi_logloss: 2.04527	valid_1's multi_logloss: 2.09346
# [105]	valid_0's multi_logloss: 2.03943	valid_1's multi_logloss: 2.0906
# [110]	valid_0's multi_logloss: 2.0338	valid_1's multi_logloss: 2.08795
# [115]	valid_0's multi_logloss: 2.02856	valid_1's multi_logloss: 2.08574
# [120]	valid_0's multi_logloss: 2.0237	valid_1's multi_logloss: 2.08392
# [125]	valid_0's multi_logloss: 2.01917	valid_1's multi_logloss: 2.08244
# [130]	valid_0's multi_logloss: 2.01474	valid_1's multi_logloss: 2.08106
# [135]	valid_0's multi_logloss: 2.01046	valid_1's multi_logloss: 2.07987
# [140]	valid_0's multi_logloss: 2.00622	valid_1's multi_logloss: 2.07871
# [145]	valid_0's multi_logloss: 2.00225	valid_1's multi_logloss: 2.07781
# [150]	valid_0's multi_logloss: 1.99834	valid_1's multi_logloss: 2.07701
# [155]	valid_0's multi_logloss: 1.99469	valid_1's multi_logloss: 2.07638
# [160]	valid_0's multi_logloss: 1.99101	valid_1's multi_logloss: 2.07577
# [165]	valid_0's multi_logloss: 1.98747	valid_1's multi_logloss: 2.07525
# [170]	valid_0's multi_logloss: 1.98402	valid_1's multi_logloss: 2.07475
# [175]	valid_0's multi_logloss: 1.98067	valid_1's multi_logloss: 2.07428
# [180]	valid_0's multi_logloss: 1.97734	valid_1's multi_logloss: 2.07383
# [185]	valid_0's multi_logloss: 1.97413	valid_1's multi_logloss: 2.07349
# [190]	valid_0's multi_logloss: 1.97085	valid_1's multi_logloss: 2.07308
# [195]	valid_0's multi_logloss: 1.96769	valid_1's multi_logloss: 2.07268
# [200]	valid_0's multi_logloss: 1.9646	valid_1's multi_logloss: 2.07235
# [205]	valid_0's multi_logloss: 1.9617	valid_1's multi_logloss: 2.07215
# [210]	valid_0's multi_logloss: 1.95879	valid_1's multi_logloss: 2.07194
# [215]	valid_0's multi_logloss: 1.95594	valid_1's multi_logloss: 2.07178
# [220]	valid_0's multi_logloss: 1.95318	valid_1's multi_logloss: 2.07163
# [225]	valid_0's multi_logloss: 1.95042	valid_1's multi_logloss: 2.07146
# [230]	valid_0's multi_logloss: 1.94773	valid_1's multi_logloss: 2.07127
# [235]	valid_0's multi_logloss: 1.94508	valid_1's multi_logloss: 2.07113
# [240]	valid_0's multi_logloss: 1.94242	valid_1's multi_logloss: 2.071
# [245]	valid_0's multi_logloss: 1.93982	valid_1's multi_logloss: 2.07088
# [250]	valid_0's multi_logloss: 1.93723	valid_1's multi_logloss: 2.07069
# [255]	valid_0's multi_logloss: 1.93468	valid_1's multi_logloss: 2.07051
# [260]	valid_0's multi_logloss: 1.93213	valid_1's multi_logloss: 2.07036
# [265]	valid_0's multi_logloss: 1.92967	valid_1's multi_logloss: 2.07026
# [270]	valid_0's multi_logloss: 1.92723	valid_1's multi_logloss: 2.0701
# [275]	valid_0's multi_logloss: 1.92483	valid_1's multi_logloss: 2.06997
# [280]	valid_0's multi_logloss: 1.92238	valid_1's multi_logloss: 2.0699
# [285]	valid_0's multi_logloss: 1.92002	valid_1's multi_logloss: 2.06975
# [290]	valid_0's multi_logloss: 1.9177	valid_1's multi_logloss: 2.06968
# [295]	valid_0's multi_logloss: 1.9154	valid_1's multi_logloss: 2.06961
# [300]	valid_0's multi_logloss: 1.91316	valid_1's multi_logloss: 2.06951
# [305]	valid_0's multi_logloss: 1.91095	valid_1's multi_logloss: 2.06945
# [310]	valid_0's multi_logloss: 1.90871	valid_1's multi_logloss: 2.06935
# [315]	valid_0's multi_logloss: 1.90644	valid_1's multi_logloss: 2.06932
# [320]	valid_0's multi_logloss: 1.90421	valid_1's multi_logloss: 2.06928
# [325]	valid_0's multi_logloss: 1.90207	valid_1's multi_logloss: 2.06928
# [330]	valid_0's multi_logloss: 1.89992	valid_1's multi_logloss: 2.06924
# [335]	valid_0's multi_logloss: 1.89779	valid_1's multi_logloss: 2.06923
# [340]	valid_0's multi_logloss: 1.89566	valid_1's multi_logloss: 2.06916
# [345]	valid_0's multi_logloss: 1.89356	valid_1's multi_logloss: 2.06914
# [350]	valid_0's multi_logloss: 1.89142	valid_1's multi_logloss: 2.06909
# [355]	valid_0's multi_logloss: 1.88932	valid_1's multi_logloss: 2.06903
# [360]	valid_0's multi_logloss: 1.88727	valid_1's multi_logloss: 2.06901
# [365]	valid_0's multi_logloss: 1.88523	valid_1's multi_logloss: 2.06901
# [370]	valid_0's multi_logloss: 1.88316	valid_1's multi_logloss: 2.06893
# [375]	valid_0's multi_logloss: 1.88111	valid_1's multi_logloss: 2.06882
# [380]	valid_0's multi_logloss: 1.87902	valid_1's multi_logloss: 2.06876
# [385]	valid_0's multi_logloss: 1.87706	valid_1's multi_logloss: 2.06877
# [390]	valid_0's multi_logloss: 1.87506	valid_1's multi_logloss: 2.06875
# [395]	valid_0's multi_logloss: 1.87308	valid_1's multi_logloss: 2.06874
# [400]	valid_0's multi_logloss: 1.87113	valid_1's multi_logloss: 2.06874
# [405]	valid_0's multi_logloss: 1.8692	valid_1's multi_logloss: 2.06871
# [410]	valid_0's multi_logloss: 1.86726	valid_1's multi_logloss: 2.06868
# [415]	valid_0's multi_logloss: 1.86538	valid_1's multi_logloss: 2.06866
# [420]	valid_0's multi_logloss: 1.86346	valid_1's multi_logloss: 2.06861
# [425]	valid_0's multi_logloss: 1.86154	valid_1's multi_logloss: 2.06858
# [430]	valid_0's multi_logloss: 1.85968	valid_1's multi_logloss: 2.06858
# [435]	valid_0's multi_logloss: 1.85778	valid_1's multi_logloss: 2.06856
# [440]	valid_0's multi_logloss: 1.85593	valid_1's multi_logloss: 2.06857
# [445]	valid_0's multi_logloss: 1.85403	valid_1's multi_logloss: 2.06855
# [450]	valid_0's multi_logloss: 1.85221	valid_1's multi_logloss: 2.06855
# [455]	valid_0's multi_logloss: 1.85039	valid_1's multi_logloss: 2.06855
# [460]	valid_0's multi_logloss: 1.84855	valid_1's multi_logloss: 2.06856
# [465]	valid_0's multi_logloss: 1.84673	valid_1's multi_logloss: 2.06859
# [470]	valid_0's multi_logloss: 1.84497	valid_1's multi_logloss: 2.0686
# [475]	valid_0's multi_logloss: 1.84319	valid_1's multi_logloss: 2.06861
# [480]	valid_0's multi_logloss: 1.84144	valid_1's multi_logloss: 2.0686
# [485]	valid_0's multi_logloss: 1.83966	valid_1's multi_logloss: 2.06858
# [490]	valid_0's multi_logloss: 1.83791	valid_1's multi_logloss: 2.06859
# [495]	valid_0's multi_logloss: 1.83606	valid_1's multi_logloss: 2.06854
# [500]	valid_0's multi_logloss: 1.83432	valid_1's multi_logloss: 2.06851
# [505]	valid_0's multi_logloss: 1.83259	valid_1's multi_logloss: 2.06853
# [510]	valid_0's multi_logloss: 1.83086	valid_1's multi_logloss: 2.06853
# [515]	valid_0's multi_logloss: 1.82914	valid_1's multi_logloss: 2.06854
# [520]	valid_0's multi_logloss: 1.82741	valid_1's multi_logloss: 2.06853
# [525]	valid_0's multi_logloss: 1.82568	valid_1's multi_logloss: 2.06855
# [530]	valid_0's multi_logloss: 1.82396	valid_1's multi_logloss: 2.06856
# [535]	valid_0's multi_logloss: 1.82228	valid_1's multi_logloss: 2.06858
# [540]	valid_0's multi_logloss: 1.82062	valid_1's multi_logloss: 2.06861
# [545]	valid_0's multi_logloss: 1.8189	valid_1's multi_logloss: 2.06863
# [550]	valid_0's multi_logloss: 1.81723	valid_1's multi_logloss: 2.06863
# [555]	valid_0's multi_logloss: 1.81559	valid_1's multi_logloss: 2.06866
# [560]	valid_0's multi_logloss: 1.81397	valid_1's multi_logloss: 2.06867
# [565]	valid_0's multi_logloss: 1.81231	valid_1's multi_logloss: 2.06866
# [570]	valid_0's multi_logloss: 1.81064	valid_1's multi_logloss: 2.06866
# [575]	valid_0's multi_logloss: 1.809	valid_1's multi_logloss: 2.06867
# [580]	valid_0's multi_logloss: 1.80736	valid_1's multi_logloss: 2.06869
# [585]	valid_0's multi_logloss: 1.80572	valid_1's multi_logloss: 2.06868
# [590]	valid_0's multi_logloss: 1.80408	valid_1's multi_logloss: 2.06868
# [595]	valid_0's multi_logloss: 1.80245	valid_1's multi_logloss: 2.06871
# [600]	valid_0's multi_logloss: 1.80082	valid_1's multi_logloss: 2.06873
# Early stopping, best iteration is:
# [500]	valid_0's multi_logloss: 1.83432	valid_1's multi_logloss: 2.06851
# val rmse: 466.594950148685
# val mae: 287.4380643284115
# runtime: 4616.241923093796
#
# 2 fold...
# Training until validation scores don't improve for 100 rounds.
# [5]	valid_0's multi_logloss: 2.94712	valid_1's multi_logloss: 2.95043
# [10]	valid_0's multi_logloss: 2.70534	valid_1's multi_logloss: 2.7111
# [15]	valid_0's multi_logloss: 2.55295	valid_1's multi_logloss: 2.5609
# [20]	valid_0's multi_logloss: 2.44553	valid_1's multi_logloss: 2.4557
# [25]	valid_0's multi_logloss: 2.36628	valid_1's multi_logloss: 2.37855
# [30]	valid_0's multi_logloss: 2.30541	valid_1's multi_logloss: 2.31985
# [35]	valid_0's multi_logloss: 2.25743	valid_1's multi_logloss: 2.27396
# [40]	valid_0's multi_logloss: 2.21913	valid_1's multi_logloss: 2.23786
# [45]	valid_0's multi_logloss: 2.1882	valid_1's multi_logloss: 2.2091
# [50]	valid_0's multi_logloss: 2.16264	valid_1's multi_logloss: 2.18581
# [55]	valid_0's multi_logloss: 2.1417	valid_1's multi_logloss: 2.16719
# [60]	valid_0's multi_logloss: 2.12382	valid_1's multi_logloss: 2.15164
# [65]	valid_0's multi_logloss: 2.10882	valid_1's multi_logloss: 2.13907
# [70]	valid_0's multi_logloss: 2.09605	valid_1's multi_logloss: 2.12878
# [75]	valid_0's multi_logloss: 2.08493	valid_1's multi_logloss: 2.12023
# [80]	valid_0's multi_logloss: 2.0751	valid_1's multi_logloss: 2.11303
# [85]	valid_0's multi_logloss: 2.06645	valid_1's multi_logloss: 2.10709
# [90]	valid_0's multi_logloss: 2.05832	valid_1's multi_logloss: 2.1018
# [95]	valid_0's multi_logloss: 2.05131	valid_1's multi_logloss: 2.09764
# [100]	valid_0's multi_logloss: 2.04496	valid_1's multi_logloss: 2.09417
# [105]	valid_0's multi_logloss: 2.03909	valid_1's multi_logloss: 2.09135
# [110]	valid_0's multi_logloss: 2.03354	valid_1's multi_logloss: 2.08879
# [115]	valid_0's multi_logloss: 2.02832	valid_1's multi_logloss: 2.08656
# [120]	valid_0's multi_logloss: 2.02332	valid_1's multi_logloss: 2.08465
# [125]	valid_0's multi_logloss: 2.01879	valid_1's multi_logloss: 2.0831
# [130]	valid_0's multi_logloss: 2.0144	valid_1's multi_logloss: 2.08174
# [135]	valid_0's multi_logloss: 2.01017	valid_1's multi_logloss: 2.08055
# [140]	valid_0's multi_logloss: 2.00605	valid_1's multi_logloss: 2.07948
# [145]	valid_0's multi_logloss: 2.00216	valid_1's multi_logloss: 2.07873
# [150]	valid_0's multi_logloss: 1.99841	valid_1's multi_logloss: 2.078
# [155]	valid_0's multi_logloss: 1.9947	valid_1's multi_logloss: 2.07732
# [160]	valid_0's multi_logloss: 1.99083	valid_1's multi_logloss: 2.07648
# [165]	valid_0's multi_logloss: 1.98723	valid_1's multi_logloss: 2.07588
# [170]	valid_0's multi_logloss: 1.98383	valid_1's multi_logloss: 2.07545
# [175]	valid_0's multi_logloss: 1.98044	valid_1's multi_logloss: 2.07504
# [180]	valid_0's multi_logloss: 1.97719	valid_1's multi_logloss: 2.07464
# [185]	valid_0's multi_logloss: 1.97404	valid_1's multi_logloss: 2.07439
# [190]	valid_0's multi_logloss: 1.97079	valid_1's multi_logloss: 2.07397
# [195]	valid_0's multi_logloss: 1.9677	valid_1's multi_logloss: 2.07371
# [200]	valid_0's multi_logloss: 1.96471	valid_1's multi_logloss: 2.07349
# [205]	valid_0's multi_logloss: 1.9617	valid_1's multi_logloss: 2.07321
# [210]	valid_0's multi_logloss: 1.95872	valid_1's multi_logloss: 2.07296
# [215]	valid_0's multi_logloss: 1.95583	valid_1's multi_logloss: 2.07274
# [220]	valid_0's multi_logloss: 1.95307	valid_1's multi_logloss: 2.07258
# [225]	valid_0's multi_logloss: 1.95029	valid_1's multi_logloss: 2.07243
# [230]	valid_0's multi_logloss: 1.94761	valid_1's multi_logloss: 2.07231
# [235]	valid_0's multi_logloss: 1.9449	valid_1's multi_logloss: 2.07214
# [240]	valid_0's multi_logloss: 1.94227	valid_1's multi_logloss: 2.07201
# [245]	valid_0's multi_logloss: 1.93964	valid_1's multi_logloss: 2.07182
# [250]	valid_0's multi_logloss: 1.93697	valid_1's multi_logloss: 2.07165
# [255]	valid_0's multi_logloss: 1.93445	valid_1's multi_logloss: 2.07151
# [260]	valid_0's multi_logloss: 1.93183	valid_1's multi_logloss: 2.07135
# [265]	valid_0's multi_logloss: 1.92932	valid_1's multi_logloss: 2.07123
# [270]	valid_0's multi_logloss: 1.92689	valid_1's multi_logloss: 2.07113
# [275]	valid_0's multi_logloss: 1.92446	valid_1's multi_logloss: 2.07103
# [280]	valid_0's multi_logloss: 1.92203	valid_1's multi_logloss: 2.07093
# [285]	valid_0's multi_logloss: 1.91962	valid_1's multi_logloss: 2.07087
# [290]	valid_0's multi_logloss: 1.91729	valid_1's multi_logloss: 2.07077
# [295]	valid_0's multi_logloss: 1.91498	valid_1's multi_logloss: 2.07067
# [300]	valid_0's multi_logloss: 1.9127	valid_1's multi_logloss: 2.07058
# [305]	valid_0's multi_logloss: 1.91039	valid_1's multi_logloss: 2.07049
# [310]	valid_0's multi_logloss: 1.90812	valid_1's multi_logloss: 2.07042
# [315]	valid_0's multi_logloss: 1.90585	valid_1's multi_logloss: 2.07035
# [320]	valid_0's multi_logloss: 1.90363	valid_1's multi_logloss: 2.0703
# [325]	valid_0's multi_logloss: 1.90144	valid_1's multi_logloss: 2.0703
# [330]	valid_0's multi_logloss: 1.89928	valid_1's multi_logloss: 2.07025
# [335]	valid_0's multi_logloss: 1.89712	valid_1's multi_logloss: 2.07022
# [340]	valid_0's multi_logloss: 1.89502	valid_1's multi_logloss: 2.07017
# [345]	valid_0's multi_logloss: 1.89288	valid_1's multi_logloss: 2.07014
# [350]	valid_0's multi_logloss: 1.89075	valid_1's multi_logloss: 2.07008
# [355]	valid_0's multi_logloss: 1.8887	valid_1's multi_logloss: 2.07009
# [360]	valid_0's multi_logloss: 1.88664	valid_1's multi_logloss: 2.07007
# [365]	valid_0's multi_logloss: 1.88462	valid_1's multi_logloss: 2.07002
# [370]	valid_0's multi_logloss: 1.88258	valid_1's multi_logloss: 2.07001
# [375]	valid_0's multi_logloss: 1.8806	valid_1's multi_logloss: 2.07003
# [380]	valid_0's multi_logloss: 1.87854	valid_1's multi_logloss: 2.06994
# [385]	valid_0's multi_logloss: 1.87656	valid_1's multi_logloss: 2.06993
# [390]	valid_0's multi_logloss: 1.87452	valid_1's multi_logloss: 2.06987
# [395]	valid_0's multi_logloss: 1.87253	valid_1's multi_logloss: 2.06985
# [400]	valid_0's multi_logloss: 1.87059	valid_1's multi_logloss: 2.06983
# [405]	valid_0's multi_logloss: 1.86861	valid_1's multi_logloss: 2.0698
# [410]	valid_0's multi_logloss: 1.8667	valid_1's multi_logloss: 2.06979
# [415]	valid_0's multi_logloss: 1.86476	valid_1's multi_logloss: 2.06976
# [420]	valid_0's multi_logloss: 1.86277	valid_1's multi_logloss: 2.06971
# [425]	valid_0's multi_logloss: 1.86089	valid_1's multi_logloss: 2.06972
# [430]	valid_0's multi_logloss: 1.85899	valid_1's multi_logloss: 2.06973
# [435]	valid_0's multi_logloss: 1.85711	valid_1's multi_logloss: 2.06968
# [440]	valid_0's multi_logloss: 1.85519	valid_1's multi_logloss: 2.06968
# [445]	valid_0's multi_logloss: 1.85334	valid_1's multi_logloss: 2.06971
# [450]	valid_0's multi_logloss: 1.85148	valid_1's multi_logloss: 2.06969
# [455]	valid_0's multi_logloss: 1.84965	valid_1's multi_logloss: 2.0697
# [460]	valid_0's multi_logloss: 1.84787	valid_1's multi_logloss: 2.06973
# [465]	valid_0's multi_logloss: 1.84608	valid_1's multi_logloss: 2.06971
# [470]	valid_0's multi_logloss: 1.84427	valid_1's multi_logloss: 2.06973
# [475]	valid_0's multi_logloss: 1.84246	valid_1's multi_logloss: 2.06974
# [480]	valid_0's multi_logloss: 1.84066	valid_1's multi_logloss: 2.06974
# [485]	valid_0's multi_logloss: 1.83889	valid_1's multi_logloss: 2.06977
# [490]	valid_0's multi_logloss: 1.83711	valid_1's multi_logloss: 2.06976
# [495]	valid_0's multi_logloss: 1.83532	valid_1's multi_logloss: 2.06971
# [500]	valid_0's multi_logloss: 1.83358	valid_1's multi_logloss: 2.06971
# [505]	valid_0's multi_logloss: 1.83182	valid_1's multi_logloss: 2.06971
# [510]	valid_0's multi_logloss: 1.83009	valid_1's multi_logloss: 2.06973
# [515]	valid_0's multi_logloss: 1.82834	valid_1's multi_logloss: 2.06974
# [520]	valid_0's multi_logloss: 1.82662	valid_1's multi_logloss: 2.06974
# [525]	valid_0's multi_logloss: 1.82489	valid_1's multi_logloss: 2.06975
# [530]	valid_0's multi_logloss: 1.82317	valid_1's multi_logloss: 2.06974
# [535]	valid_0's multi_logloss: 1.82151	valid_1's multi_logloss: 2.06973
# [540]	valid_0's multi_logloss: 1.81983	valid_1's multi_logloss: 2.06978
# Early stopping, best iteration is:
# [440]	valid_0's multi_logloss: 1.85519	valid_1's multi_logloss: 2.06968
# val rmse: 465.70253420227607
# val mae: 287.36182215584085
# runtime: 4981.274259805679
#
# 3 fold...
# Training until validation scores don't improve for 100 rounds.
# [5]	valid_0's multi_logloss: 2.94714	valid_1's multi_logloss: 2.95028
# [10]	valid_0's multi_logloss: 2.70556	valid_1's multi_logloss: 2.71098
# [15]	valid_0's multi_logloss: 2.55271	valid_1's multi_logloss: 2.56027
# [20]	valid_0's multi_logloss: 2.4456	valid_1's multi_logloss: 2.45524
# [25]	valid_0's multi_logloss: 2.36647	valid_1's multi_logloss: 2.37816
# [30]	valid_0's multi_logloss: 2.30543	valid_1's multi_logloss: 2.31917
# [35]	valid_0's multi_logloss: 2.25727	valid_1's multi_logloss: 2.27309
# [40]	valid_0's multi_logloss: 2.21893	valid_1's multi_logloss: 2.23685
# [45]	valid_0's multi_logloss: 2.18807	valid_1's multi_logloss: 2.20822
# [50]	valid_0's multi_logloss: 2.16253	valid_1's multi_logloss: 2.18493
# [55]	valid_0's multi_logloss: 2.14183	valid_1's multi_logloss: 2.16652
# [60]	valid_0's multi_logloss: 2.12416	valid_1's multi_logloss: 2.15122
# [65]	valid_0's multi_logloss: 2.10863	valid_1's multi_logloss: 2.13818
# [70]	valid_0's multi_logloss: 2.09589	valid_1's multi_logloss: 2.12789
# [75]	valid_0's multi_logloss: 2.08449	valid_1's multi_logloss: 2.11909
# [80]	valid_0's multi_logloss: 2.07491	valid_1's multi_logloss: 2.11215
# [85]	valid_0's multi_logloss: 2.06617	valid_1's multi_logloss: 2.10611
# [90]	valid_0's multi_logloss: 2.05848	valid_1's multi_logloss: 2.10119
# [95]	valid_0's multi_logloss: 2.05141	valid_1's multi_logloss: 2.09695
# [100]	valid_0's multi_logloss: 2.04477	valid_1's multi_logloss: 2.09328
# [105]	valid_0's multi_logloss: 2.03872	valid_1's multi_logloss: 2.0902
# [110]	valid_0's multi_logloss: 2.03328	valid_1's multi_logloss: 2.08772
# [115]	valid_0's multi_logloss: 2.02805	valid_1's multi_logloss: 2.08544
# [120]	valid_0's multi_logloss: 2.02332	valid_1's multi_logloss: 2.08378
# [125]	valid_0's multi_logloss: 2.01868	valid_1's multi_logloss: 2.08225
# [130]	valid_0's multi_logloss: 2.01427	valid_1's multi_logloss: 2.08086
# [135]	valid_0's multi_logloss: 2.01007	valid_1's multi_logloss: 2.07978
# [140]	valid_0's multi_logloss: 2.00585	valid_1's multi_logloss: 2.07866
# [145]	valid_0's multi_logloss: 2.00196	valid_1's multi_logloss: 2.07775
# [150]	valid_0's multi_logloss: 1.99813	valid_1's multi_logloss: 2.07693
# [155]	valid_0's multi_logloss: 1.99434	valid_1's multi_logloss: 2.07621
# [160]	valid_0's multi_logloss: 1.99068	valid_1's multi_logloss: 2.07558
# [165]	valid_0's multi_logloss: 1.98716	valid_1's multi_logloss: 2.07509
# [170]	valid_0's multi_logloss: 1.98368	valid_1's multi_logloss: 2.07465
# [175]	valid_0's multi_logloss: 1.98036	valid_1's multi_logloss: 2.0743
# [180]	valid_0's multi_logloss: 1.9772	valid_1's multi_logloss: 2.07402
# [185]	valid_0's multi_logloss: 1.97386	valid_1's multi_logloss: 2.07353
# [190]	valid_0's multi_logloss: 1.97074	valid_1's multi_logloss: 2.07324
# [195]	valid_0's multi_logloss: 1.96766	valid_1's multi_logloss: 2.07287
# [200]	valid_0's multi_logloss: 1.96456	valid_1's multi_logloss: 2.07262
# [205]	valid_0's multi_logloss: 1.96155	valid_1's multi_logloss: 2.07235
# [210]	valid_0's multi_logloss: 1.95866	valid_1's multi_logloss: 2.0721
# [215]	valid_0's multi_logloss: 1.95578	valid_1's multi_logloss: 2.07188
# [220]	valid_0's multi_logloss: 1.95295	valid_1's multi_logloss: 2.07164
# [225]	valid_0's multi_logloss: 1.95022	valid_1's multi_logloss: 2.07148
# [230]	valid_0's multi_logloss: 1.94746	valid_1's multi_logloss: 2.07129
# [235]	valid_0's multi_logloss: 1.94466	valid_1's multi_logloss: 2.07099
# [240]	valid_0's multi_logloss: 1.94196	valid_1's multi_logloss: 2.07081
# [245]	valid_0's multi_logloss: 1.93933	valid_1's multi_logloss: 2.07067
# [250]	valid_0's multi_logloss: 1.93674	valid_1's multi_logloss: 2.07054
# [255]	valid_0's multi_logloss: 1.93422	valid_1's multi_logloss: 2.07042
# [260]	valid_0's multi_logloss: 1.93182	valid_1's multi_logloss: 2.07036
# [265]	valid_0's multi_logloss: 1.92941	valid_1's multi_logloss: 2.07029
# [270]	valid_0's multi_logloss: 1.92702	valid_1's multi_logloss: 2.07023
# [275]	valid_0's multi_logloss: 1.92458	valid_1's multi_logloss: 2.07007
# [280]	valid_0's multi_logloss: 1.92216	valid_1's multi_logloss: 2.07003
# [285]	valid_0's multi_logloss: 1.91981	valid_1's multi_logloss: 2.07
# [290]	valid_0's multi_logloss: 1.91747	valid_1's multi_logloss: 2.06993
# [295]	valid_0's multi_logloss: 1.91512	valid_1's multi_logloss: 2.06984
# [300]	valid_0's multi_logloss: 1.91291	valid_1's multi_logloss: 2.0698
# [305]	valid_0's multi_logloss: 1.91066	valid_1's multi_logloss: 2.06968
# [310]	valid_0's multi_logloss: 1.9084	valid_1's multi_logloss: 2.06963
# [315]	valid_0's multi_logloss: 1.90614	valid_1's multi_logloss: 2.06952
# [320]	valid_0's multi_logloss: 1.90391	valid_1's multi_logloss: 2.06945
# [325]	valid_0's multi_logloss: 1.90174	valid_1's multi_logloss: 2.06943
# [330]	valid_0's multi_logloss: 1.89952	valid_1's multi_logloss: 2.06933
# [335]	valid_0's multi_logloss: 1.89736	valid_1's multi_logloss: 2.06927
# [340]	valid_0's multi_logloss: 1.89525	valid_1's multi_logloss: 2.06924
# [345]	valid_0's multi_logloss: 1.89308	valid_1's multi_logloss: 2.06917
# [350]	valid_0's multi_logloss: 1.89099	valid_1's multi_logloss: 2.06914
# [355]	valid_0's multi_logloss: 1.88894	valid_1's multi_logloss: 2.06911
# [360]	valid_0's multi_logloss: 1.88688	valid_1's multi_logloss: 2.06907
# [365]	valid_0's multi_logloss: 1.88486	valid_1's multi_logloss: 2.06903
# [370]	valid_0's multi_logloss: 1.88278	valid_1's multi_logloss: 2.06898
# [375]	valid_0's multi_logloss: 1.88075	valid_1's multi_logloss: 2.06895
# [380]	valid_0's multi_logloss: 1.87875	valid_1's multi_logloss: 2.06894
# [385]	valid_0's multi_logloss: 1.87677	valid_1's multi_logloss: 2.06895
# [390]	valid_0's multi_logloss: 1.87477	valid_1's multi_logloss: 2.06892
# [395]	valid_0's multi_logloss: 1.87279	valid_1's multi_logloss: 2.06892
# [400]	valid_0's multi_logloss: 1.8708	valid_1's multi_logloss: 2.06888
# [405]	valid_0's multi_logloss: 1.86891	valid_1's multi_logloss: 2.06891
# [410]	valid_0's multi_logloss: 1.86699	valid_1's multi_logloss: 2.06886
# [415]	valid_0's multi_logloss: 1.86501	valid_1's multi_logloss: 2.06884
# [420]	valid_0's multi_logloss: 1.86312	valid_1's multi_logloss: 2.0688
# [425]	valid_0's multi_logloss: 1.86123	valid_1's multi_logloss: 2.0688
# [430]	valid_0's multi_logloss: 1.85936	valid_1's multi_logloss: 2.06881
# [435]	valid_0's multi_logloss: 1.85752	valid_1's multi_logloss: 2.06884
# [440]	valid_0's multi_logloss: 1.85564	valid_1's multi_logloss: 2.06882
# [445]	valid_0's multi_logloss: 1.85377	valid_1's multi_logloss: 2.06881
# [450]	valid_0's multi_logloss: 1.85196	valid_1's multi_logloss: 2.0688
# [455]	valid_0's multi_logloss: 1.85006	valid_1's multi_logloss: 2.06877
# [460]	valid_0's multi_logloss: 1.84825	valid_1's multi_logloss: 2.06878
# [465]	valid_0's multi_logloss: 1.84641	valid_1's multi_logloss: 2.06875
# [470]	valid_0's multi_logloss: 1.84465	valid_1's multi_logloss: 2.06878
# [475]	valid_0's multi_logloss: 1.84285	valid_1's multi_logloss: 2.06879
# [480]	valid_0's multi_logloss: 1.84102	valid_1's multi_logloss: 2.06875
# [485]	valid_0's multi_logloss: 1.83919	valid_1's multi_logloss: 2.06871
# [490]	valid_0's multi_logloss: 1.83747	valid_1's multi_logloss: 2.06871
# [495]	valid_0's multi_logloss: 1.83571	valid_1's multi_logloss: 2.06874
# [500]	valid_0's multi_logloss: 1.83396	valid_1's multi_logloss: 2.0687
# [505]	valid_0's multi_logloss: 1.8322	valid_1's multi_logloss: 2.06871
# [510]	valid_0's multi_logloss: 1.83044	valid_1's multi_logloss: 2.06871
# [515]	valid_0's multi_logloss: 1.82871	valid_1's multi_logloss: 2.06871
# [520]	valid_0's multi_logloss: 1.82697	valid_1's multi_logloss: 2.0687
# [525]	valid_0's multi_logloss: 1.82525	valid_1's multi_logloss: 2.06868
# [530]	valid_0's multi_logloss: 1.82355	valid_1's multi_logloss: 2.06871
# [535]	valid_0's multi_logloss: 1.82186	valid_1's multi_logloss: 2.0687
# [540]	valid_0's multi_logloss: 1.8202	valid_1's multi_logloss: 2.06872
# [545]	valid_0's multi_logloss: 1.81851	valid_1's multi_logloss: 2.06874
# [550]	valid_0's multi_logloss: 1.81687	valid_1's multi_logloss: 2.06875
# [555]	valid_0's multi_logloss: 1.81521	valid_1's multi_logloss: 2.06877
# [560]	valid_0's multi_logloss: 1.81351	valid_1's multi_logloss: 2.0688
# [565]	valid_0's multi_logloss: 1.81189	valid_1's multi_logloss: 2.06884
# [570]	valid_0's multi_logloss: 1.81026	valid_1's multi_logloss: 2.06887
# [575]	valid_0's multi_logloss: 1.8086	valid_1's multi_logloss: 2.06888
# [580]	valid_0's multi_logloss: 1.80699	valid_1's multi_logloss: 2.06894
# [585]	valid_0's multi_logloss: 1.80534	valid_1's multi_logloss: 2.06902
# [590]	valid_0's multi_logloss: 1.80366	valid_1's multi_logloss: 2.06898
# [595]	valid_0's multi_logloss: 1.80202	valid_1's multi_logloss: 2.06903
# [600]	valid_0's multi_logloss: 1.80042	valid_1's multi_logloss: 2.06906
# [605]	valid_0's multi_logloss: 1.79885	valid_1's multi_logloss: 2.06909
# [610]	valid_0's multi_logloss: 1.79726	valid_1's multi_logloss: 2.06912
# [615]	valid_0's multi_logloss: 1.79565	valid_1's multi_logloss: 2.06913
# [620]	valid_0's multi_logloss: 1.79412	valid_1's multi_logloss: 2.06918
# [625]	valid_0's multi_logloss: 1.79254	valid_1's multi_logloss: 2.0692
# Early stopping, best iteration is:
# [525]	valid_0's multi_logloss: 1.82525	valid_1's multi_logloss: 2.06868
# val rmse: 469.1239913679715
# val mae: 288.8743885205344
# runtime: 5010.18620634079
#
# 4 fold...
# Training until validation scores don't improve for 100 rounds.
# [5]	valid_0's multi_logloss: 2.94726	valid_1's multi_logloss: 2.9511
# [10]	valid_0's multi_logloss: 2.70492	valid_1's multi_logloss: 2.71146
# [15]	valid_0's multi_logloss: 2.55187	valid_1's multi_logloss: 2.56063
# [20]	valid_0's multi_logloss: 2.44514	valid_1's multi_logloss: 2.4561
# [25]	valid_0's multi_logloss: 2.36629	valid_1's multi_logloss: 2.37932
# [30]	valid_0's multi_logloss: 2.30534	valid_1's multi_logloss: 2.32054
# [35]	valid_0's multi_logloss: 2.25725	valid_1's multi_logloss: 2.27453
# [40]	valid_0's multi_logloss: 2.21887	valid_1's multi_logloss: 2.23829
# [45]	valid_0's multi_logloss: 2.18824	valid_1's multi_logloss: 2.20983
# [50]	valid_0's multi_logloss: 2.16255	valid_1's multi_logloss: 2.18639
# [55]	valid_0's multi_logloss: 2.14182	valid_1's multi_logloss: 2.16793
# [60]	valid_0's multi_logloss: 2.12412	valid_1's multi_logloss: 2.15253
# [65]	valid_0's multi_logloss: 2.10869	valid_1's multi_logloss: 2.13951
# [70]	valid_0's multi_logloss: 2.09605	valid_1's multi_logloss: 2.12934
# [75]	valid_0's multi_logloss: 2.08474	valid_1's multi_logloss: 2.12057
# [80]	valid_0's multi_logloss: 2.07508	valid_1's multi_logloss: 2.1135
# [85]	valid_0's multi_logloss: 2.06633	valid_1's multi_logloss: 2.10747
# [90]	valid_0's multi_logloss: 2.05865	valid_1's multi_logloss: 2.1025
# [95]	valid_0's multi_logloss: 2.05155	valid_1's multi_logloss: 2.09826
# [100]	valid_0's multi_logloss: 2.04509	valid_1's multi_logloss: 2.09462
# [105]	valid_0's multi_logloss: 2.03924	valid_1's multi_logloss: 2.09162
# [110]	valid_0's multi_logloss: 2.03378	valid_1's multi_logloss: 2.08907
# [115]	valid_0's multi_logloss: 2.02856	valid_1's multi_logloss: 2.08684
# [120]	valid_0's multi_logloss: 2.02368	valid_1's multi_logloss: 2.08497
# [125]	valid_0's multi_logloss: 2.01901	valid_1's multi_logloss: 2.08326
# [130]	valid_0's multi_logloss: 2.01464	valid_1's multi_logloss: 2.08198
# [135]	valid_0's multi_logloss: 2.01043	valid_1's multi_logloss: 2.0808
# [140]	valid_0's multi_logloss: 2.00634	valid_1's multi_logloss: 2.07975
# [145]	valid_0's multi_logloss: 2.0023	valid_1's multi_logloss: 2.0788
# [150]	valid_0's multi_logloss: 1.99854	valid_1's multi_logloss: 2.07808
# [155]	valid_0's multi_logloss: 1.99468	valid_1's multi_logloss: 2.07727
# [160]	valid_0's multi_logloss: 1.99109	valid_1's multi_logloss: 2.07666
# [165]	valid_0's multi_logloss: 1.98761	valid_1's multi_logloss: 2.07611
# [170]	valid_0's multi_logloss: 1.98415	valid_1's multi_logloss: 2.07557
# [175]	valid_0's multi_logloss: 1.98085	valid_1's multi_logloss: 2.07513
# [180]	valid_0's multi_logloss: 1.97752	valid_1's multi_logloss: 2.07468
# [185]	valid_0's multi_logloss: 1.97423	valid_1's multi_logloss: 2.07426
# [190]	valid_0's multi_logloss: 1.97116	valid_1's multi_logloss: 2.07404
# [195]	valid_0's multi_logloss: 1.96807	valid_1's multi_logloss: 2.07374
# [200]	valid_0's multi_logloss: 1.9651	valid_1's multi_logloss: 2.07349
# [205]	valid_0's multi_logloss: 1.96207	valid_1's multi_logloss: 2.07315
# [210]	valid_0's multi_logloss: 1.95918	valid_1's multi_logloss: 2.07289
# [215]	valid_0's multi_logloss: 1.95635	valid_1's multi_logloss: 2.07267
# [220]	valid_0's multi_logloss: 1.95357	valid_1's multi_logloss: 2.07246
# [225]	valid_0's multi_logloss: 1.95074	valid_1's multi_logloss: 2.07225
# [230]	valid_0's multi_logloss: 1.94804	valid_1's multi_logloss: 2.0721
# [235]	valid_0's multi_logloss: 1.94534	valid_1's multi_logloss: 2.07191
# [240]	valid_0's multi_logloss: 1.9426	valid_1's multi_logloss: 2.0717
# [245]	valid_0's multi_logloss: 1.94004	valid_1's multi_logloss: 2.07158
# [250]	valid_0's multi_logloss: 1.93745	valid_1's multi_logloss: 2.07137
# [255]	valid_0's multi_logloss: 1.93495	valid_1's multi_logloss: 2.07131
# [260]	valid_0's multi_logloss: 1.93238	valid_1's multi_logloss: 2.07108
# [265]	valid_0's multi_logloss: 1.9299	valid_1's multi_logloss: 2.07095
# [270]	valid_0's multi_logloss: 1.92749	valid_1's multi_logloss: 2.07081
# [275]	valid_0's multi_logloss: 1.92512	valid_1's multi_logloss: 2.07075
# [280]	valid_0's multi_logloss: 1.92264	valid_1's multi_logloss: 2.07057
# [285]	valid_0's multi_logloss: 1.92032	valid_1's multi_logloss: 2.07045
# [290]	valid_0's multi_logloss: 1.91798	valid_1's multi_logloss: 2.07042
# [295]	valid_0's multi_logloss: 1.91567	valid_1's multi_logloss: 2.07032
# [300]	valid_0's multi_logloss: 1.91339	valid_1's multi_logloss: 2.07026
# [305]	valid_0's multi_logloss: 1.91111	valid_1's multi_logloss: 2.07017
# [310]	valid_0's multi_logloss: 1.90882	valid_1's multi_logloss: 2.07011
# [315]	valid_0's multi_logloss: 1.90662	valid_1's multi_logloss: 2.07007
# [320]	valid_0's multi_logloss: 1.90438	valid_1's multi_logloss: 2.06997
# [325]	valid_0's multi_logloss: 1.90223	valid_1's multi_logloss: 2.06995
# [330]	valid_0's multi_logloss: 1.90014	valid_1's multi_logloss: 2.06993
# [335]	valid_0's multi_logloss: 1.89801	valid_1's multi_logloss: 2.06987
# [340]	valid_0's multi_logloss: 1.8958	valid_1's multi_logloss: 2.06976
# [345]	valid_0's multi_logloss: 1.89373	valid_1's multi_logloss: 2.06974
# [350]	valid_0's multi_logloss: 1.89154	valid_1's multi_logloss: 2.0697
# [355]	valid_0's multi_logloss: 1.88944	valid_1's multi_logloss: 2.06965
# [360]	valid_0's multi_logloss: 1.88737	valid_1's multi_logloss: 2.06958
# [365]	valid_0's multi_logloss: 1.88534	valid_1's multi_logloss: 2.06954
# [370]	valid_0's multi_logloss: 1.88333	valid_1's multi_logloss: 2.06948
# [375]	valid_0's multi_logloss: 1.88132	valid_1's multi_logloss: 2.06947
# [380]	valid_0's multi_logloss: 1.87924	valid_1's multi_logloss: 2.0694
# [385]	valid_0's multi_logloss: 1.87728	valid_1's multi_logloss: 2.06938
# [390]	valid_0's multi_logloss: 1.87527	valid_1's multi_logloss: 2.06934
# [395]	valid_0's multi_logloss: 1.87331	valid_1's multi_logloss: 2.06935
# [400]	valid_0's multi_logloss: 1.87138	valid_1's multi_logloss: 2.06934
# [405]	valid_0's multi_logloss: 1.86946	valid_1's multi_logloss: 2.06933
# [410]	valid_0's multi_logloss: 1.86747	valid_1's multi_logloss: 2.0693
# [415]	valid_0's multi_logloss: 1.8655	valid_1's multi_logloss: 2.06928
# [420]	valid_0's multi_logloss: 1.8636	valid_1's multi_logloss: 2.06927
# [425]	valid_0's multi_logloss: 1.86173	valid_1's multi_logloss: 2.06923
# [430]	valid_0's multi_logloss: 1.85987	valid_1's multi_logloss: 2.06924
# [435]	valid_0's multi_logloss: 1.85799	valid_1's multi_logloss: 2.0692
# [440]	valid_0's multi_logloss: 1.85615	valid_1's multi_logloss: 2.06919
# [445]	valid_0's multi_logloss: 1.85431	valid_1's multi_logloss: 2.0692
# [450]	valid_0's multi_logloss: 1.85247	valid_1's multi_logloss: 2.06918
# [455]	valid_0's multi_logloss: 1.85068	valid_1's multi_logloss: 2.06918
# [460]	valid_0's multi_logloss: 1.84884	valid_1's multi_logloss: 2.06917
# [465]	valid_0's multi_logloss: 1.84705	valid_1's multi_logloss: 2.06915
# [470]	valid_0's multi_logloss: 1.84526	valid_1's multi_logloss: 2.06915
# [475]	valid_0's multi_logloss: 1.84347	valid_1's multi_logloss: 2.06911
# [480]	valid_0's multi_logloss: 1.84167	valid_1's multi_logloss: 2.06907
# [485]	valid_0's multi_logloss: 1.83993	valid_1's multi_logloss: 2.06911
# [490]	valid_0's multi_logloss: 1.83815	valid_1's multi_logloss: 2.06909
# [495]	valid_0's multi_logloss: 1.8364	valid_1's multi_logloss: 2.06909
# [500]	valid_0's multi_logloss: 1.83463	valid_1's multi_logloss: 2.0691
# [505]	valid_0's multi_logloss: 1.83292	valid_1's multi_logloss: 2.06911
# [510]	valid_0's multi_logloss: 1.8312	valid_1's multi_logloss: 2.06914
# [515]	valid_0's multi_logloss: 1.82945	valid_1's multi_logloss: 2.06913
# [520]	valid_0's multi_logloss: 1.8277	valid_1's multi_logloss: 2.06915
# [525]	valid_0's multi_logloss: 1.82595	valid_1's multi_logloss: 2.06912
# [530]	valid_0's multi_logloss: 1.8243	valid_1's multi_logloss: 2.06912
# [535]	valid_0's multi_logloss: 1.82262	valid_1's multi_logloss: 2.06911
# [540]	valid_0's multi_logloss: 1.82095	valid_1's multi_logloss: 2.06914
# [545]	valid_0's multi_logloss: 1.81932	valid_1's multi_logloss: 2.06913
# [550]	valid_0's multi_logloss: 1.81764	valid_1's multi_logloss: 2.06914
# [555]	valid_0's multi_logloss: 1.81594	valid_1's multi_logloss: 2.06912
# [560]	valid_0's multi_logloss: 1.81425	valid_1's multi_logloss: 2.06911
# [565]	valid_0's multi_logloss: 1.81263	valid_1's multi_logloss: 2.06913
# [570]	valid_0's multi_logloss: 1.811	valid_1's multi_logloss: 2.06915
# [575]	valid_0's multi_logloss: 1.80935	valid_1's multi_logloss: 2.06915
# [580]	valid_0's multi_logloss: 1.8077	valid_1's multi_logloss: 2.06916
# Early stopping, best iteration is:
# [480]	valid_0's multi_logloss: 1.84167	valid_1's multi_logloss: 2.06907
# val rmse: 470.5780242229276
# val mae: 289.1553874279819
# runtime: 4776.275796890259
#
#
# cv rmse: 467.4573068320494
# cv mae: 288.23020915589484
# cv logloss: 2.0684398568163997
# cv acc: 0.415952

# %%
sub_example = pd.read_csv('dataset/submission.csv', parse_dates=['repay_date'])

sub_example = sub_example.merge(sub, on='listing_id', how='left')

sub_example['days'] = (sub_example['repay_date'] - sub_example['auditing_date']).dt.days

# shape = (-1, 33)

test_prob = sub_example[prob_cols].values

test_labels = sub_example['days'].values

test_prob = [test_prob[i][test_labels[i]] for i in range(test_prob.shape[0])]

sub_example['repay_amt'] = sub_example['due_amt'] * test_prob

sub_example[['listing_id', 'repay_date', 'repay_amt']].to_csv('sub.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-25-579287b92ece> in <module>
# ----> 1 sub_example = pd.read_csv('dataset/submission.csv', parse_dates=['repay_date'])
#       2
#       3 sub_example = sub_example.merge(sub, on='listing_id', how='left')
#       4
#       5 sub_example['days'] = (sub_example['repay_date'] - sub_example['auditing_date']).dt.days
#
# ~/anaconda2/envs/cherie_version1_cup/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# ~/anaconda2/envs/cherie_version1_cup/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     427
#     428     # Create the parser.
# --> 429     parser = TextFileReader(filepath_or_buffer, **kwds)
#     430
#     431     if chunksize or iterator:
#
# ~/anaconda2/envs/cherie_version1_cup/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options['has_index_names'] = kwds['has_index_names']
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~/anaconda2/envs/cherie_version1_cup/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1120     def _make_engine(self, engine='c'):
#    1121         if engine == 'c':
# -> 1122             self._engine = CParserWrapper(self.f, **self.options)
#    1123         else:
#    1124             if engine == 'python':
#
# ~/anaconda2/envs/cherie_version1_cup/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1851         kwds['usecols'] = self.usecols
#    1852
# -> 1853         self._reader = parsers.TextReader(src, **kwds)
#    1854         self.unnamed_cols = self._reader.unnamed_cols
#    1855
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'dataset/submission.csv' does not exist: b'dataset/submission.csv'
